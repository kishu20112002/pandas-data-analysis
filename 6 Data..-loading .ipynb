# %% [markdown]
# # DataFrame - LOADING -Different files

# %% [markdown]
# ### => How many ways ti create a DataFrame
# - Empty DataFrame
# - Using single list
# - using nested list
# - using Dictionary
# ### => by loading the file
# - csv
# - jscon
# - excel file

# %% [markdown]
# ### 1. Loading files
# - We can load different files in pandas
# - whenever we are loading the file then pandas return a Dataframe.
# - Once after DataFrame is retured then based on requirement we can perform several operations.
# ### 2. loading the file
# - csv   (comma sepersted file)
# - jscon
# - excel file
# - Tsv file  (Tab separated values)
# - Table from webpage

# %%
import pandas as pd
file=pd.read_csv('/Users/apple/Downloads/amazon.csv')
print(file)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# ### 2.1 CSV file
# - Csv file stands for comma separated file
# - A csv file contains data like rows and columns
# - whenever we are loading csv file then pandas returns DataFrame>
# - we can load csv file by using read_csv("file name with path") function

# %%
"""syntax"""
pd.read_csv('file name with path')

# %%
file.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
print(file)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# ### 2.2 json file
# - JSON stands for JavaScript Object Notation
# - in json file data is like key-value pairs and array
# - It is commonly used for transimitting data in web application
# - wherever we are loading json file then pandas returns DataFrame>
# - we can load json.file by using read_json("file name with path") function
# - value to rain based on Dictionary

# %%
"""syntax"""
pd.read_json("file name of copy path")

# %% [markdown]
# ### 2.3 excel file
# - Excel is a spreadsheet from Microsoft
# - it is using mainly to store business application data
# - Whenever we are loading excel file then pandas returns DataFrame>
# - We can load excel file by using read_excel("file name with path") function

# %%
## run below command
pip install openxl
# Out:
#   Cell In[17], line 2
#     pip install openxl
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2.4 TSV file
# - TSV stands for Tab Separated File
# - Whenever we are loading tsv file then pandas returns DataFrame.
# - we can load tsc file by using read_table("file name with path")

# %%
""" synatx"""
pd.read_table("path and file name")

# %% [markdown]
# ### 2.5 Table from webpage
# - We can load table from webpage
# - Whenever we are loading table from webpage then it pandas returns DataFrame
# - We can load csv file by using read_html("url") function

# %%
"""syntax"""
pd.read_html("url")

# %%
import pandas as pd
a=pd.read_html("https://en.wikipedia.org/wiki/The_World%27s_Billionaires")
print(a[2])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 a=pd.read_html("https://en.wikipedia.org/wiki/The_World%27s_Billionaires")
#       3 print(a[2])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# ...

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
a=pd.read_html("https://en.wikipedia.org/wiki/The_World%27s_Billionaires")
print(a[2])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 a=pd.read_html("https://en.wikipedia.org/wiki/The_World%27s_Billionaires")
#       3 print(a[2])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# ...

# %% [markdown]
# # SUMMARY

# %% [markdown]
# # 2. loading the file
# - csv   (comma sepersted file)
# - jscon
# - excel file
# - Tsv file  (Tab separated values)
# - Table from webpage
